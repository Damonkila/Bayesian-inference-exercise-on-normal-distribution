# %%
import main
import function

# %% [markdown]
# # true $(\mu,\sigma)=(2,1.5)$
# ## First run :Turn off all effect

# %%
# (N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = False, bias_selec = False, seed = False)
N = 500 
mu_true = 2 
sd_true = 1.5 
error_sd = 0.3
Nsample_for_each_obs = 5
trial = 1 
th = -0.1
err =False ## On/Off measurement error
bias = False  ## On/Off Section Bias
sdseed = True ## Fix/not fix random seed 
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = sdseed)
function.pclor(mu_true,sd_true, error_sd, Nsample_for_each_obs ,th,-50,50, perr = err, psel = bias)
# Out:
# Population =500
# Mean=2.0, SD = 1.5,
# Error on each data: None
# Bias on obs data: None
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =7
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [00:46<00:00, 856.16it/s]
# autocorr_time for each parameters= [32.1154076  32.13892767]
# $\displaystyle \mathrm{mean} = 1.902_{-0.084}^{0.084}$
# $\displaystyle \mathrm{sd} = 1.469_{-0.058}^{0.062}$
# max log prob =  -900.9170674592555
# mu= 1.8394648829431404
# sd= 1.4575250836120404
# --------------------------------
# true para log prob =  -901.7628881600433
# mu= 2
# sd= 1.5

# %% [markdown]
# # _____________________________________________________________________
# # Combine selection bias and measurement error effect
# # Mesurement error implementation is after Selection bias for simplicity
# # Second trun for an extremely perfect case to see if it can recover the normal case (nearly no effect)

# %%
N = 500 
mu_true = 2 
sd_true = 1.5
error_sd = 0.5
Nsample_for_each_obs = 2
trial = 1 
th = -3
err =True
bias = True
sdseed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = sdseed)
function.pclor(mu_true,sd_true, error_sd, Nsample_for_each_obs ,th,-50,50, perr = err, psel = bias)
# Out:
# Population =500
# Mean=2.0, SD = 1.5,
# Error on each data: Yes
# Error SD for each data = 0.5
# Number of samples for each data point =2
# Bias on obs data: Yes
# Threshold for the obs data =-2.5
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =7
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [01:43<00:00, 384.87it/s]
# autocorr_time for each parameters= [32.64654829 33.47855647]
# $\displaystyle \mathrm{mean} = 1.912_{-0.087}^{0.086}$
# $\displaystyle \mathrm{sd} = 1.465_{-0.062}^{0.067}$
# max log prob =  -905.0434225725098
# mu= 1.8394648829431404
# sd= 1.4575250836120404
# --------------------------------
# true para log prob =  -905.5461548084938
# mu= 2
# sd= 1.5

# %% [markdown]
# ## __________________________________
# ## Next :small effect: small threhold, large sample size for single event (TEST 1 )

# %%
N = 500 
mu_true = 2 
sd_true = 1.5
error_sd = 1
Nsample_for_each_obs = 5
trial = 1 
th = - 1.5
err =True
bias = True
sdseed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = sdseed)
function.pclor(mu_true,sd_true, error_sd, Nsample_for_each_obs ,th,-50,50, perr = err, psel = bias)
# Out:
# Population =500
# Mean=2.0, SD = 1.5,
# Error on each data: Yes
# Error SD for each data = 1.0
# Number of samples for each data point =5
# Bias on obs data: Yes
# Threshold for the obs data =-0.2
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =7
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [02:12<00:00, 302.02it/s]
# autocorr_time for each parameters= [34.98326917 35.23218398]
# $\displaystyle \mathrm{mean} = 1.593_{-0.362}^{0.241}$
# $\displaystyle \mathrm{sd} = 1.634_{-0.191}^{0.249}$
# max log prob =  -793.4936755330363
# mu= 1.5050167224080298
# sd= 1.6892976588628765
# --------------------------------
# true para log prob =  -796.7148784148208
# mu= 2
# sd= 1.5

# %% [markdown]
# ## _______________________________________________
# ## larger bias effect on TEST1

# %%
N = 500 
mu_true = 2 
sd_true = 1.5
error_sd = 1
Nsample_for_each_obs = 5
trial = 1 
th = - 0.5
err =True
bias = True
sdseed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = sdseed)
function.pclor(mu_true,sd_true, error_sd, Nsample_for_each_obs ,th,-50,50, perr = err, psel = bias)
# Out:
# Population =500
# Mean=2.0, SD = 1.5,
# Error on each data: Yes
# Error SD for each data = 1.0
# Number of samples for each data point =5
# Bias on obs data: Yes
# Threshold for the obs data =1.2
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =7
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [01:54<00:00, 347.85it/s]
# autocorr_time for each parameters= [72.1885034  74.91168542]
# $\displaystyle \mathrm{mean} = -34.289_{-4.098}^{3.511}$
# $\displaystyle \mathrm{sd} = 4.318_{-0.426}^{0.498}$
# max log prob =  -194.01019449094383
# mu= -32.608695652173914
# sd= 4.1063545150501675
# --------------------------------
# true para log prob =  -469.8267229077344
# mu= 2
# sd= 1.5

# %% [markdown]
# ## _______________________________________________
# ## larger measurement error effect on TEST1

# %%
N = 500 
mu_true = 2 
sd_true = 1.5
error_sd = 1.5
Nsample_for_each_obs = 5
trial = 1 
th = - 1.5
err =True
bias = True
sdseed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = sdseed)
function.pclor(mu_true,sd_true, error_sd, Nsample_for_each_obs ,th,-50,50, perr = err, psel = bias)
# Out:
# Population =500
# Mean=2.0, SD = 1.5,
# Error on each data: Yes
# Error SD for each data = 1.5
# Number of samples for each data point =5
# Bias on obs data: Yes
# Threshold for the obs data =-0.2
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =7
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [01:49<00:00, 364.03it/s]
# autocorr_time for each parameters= [42.20452726 40.764239  ]
# $\displaystyle \mathrm{mean} = -45.698_{-3.604}^{7.998}$
# $\displaystyle \mathrm{sd} = 7.879_{-0.681}^{0.497}$
# max log prob =  -613.6730151059601
# mu= -49.66555183946488
# sd= 5.993645484949833
# --------------------------------
# true para log prob =  -850.3980719263591
# mu= 2
# sd= 1.5

# %% [markdown]
# ## ________________________________________________________
# ## Larger sample size for single event based on TEST1

# %%
N = 500 
mu_true = 2 
sd_true = 1.5
error_sd = 1
Nsample_for_each_obs = 20
trial = 1 
th = - 1.5
err =True
bias = True
sdseed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = sdseed)
function.pclor(mu_true,sd_true, error_sd, Nsample_for_each_obs ,th,-50,50, perr = err, psel = bias)
# Out:
# Population =500
# Mean=2.0, SD = 1.5,
# Error on each data: Yes
# Error SD for each data = 1.0
# Number of samples for each data point =20
# Bias on obs data: Yes
# Threshold for the obs data =-0.2
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =7
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [03:27<00:00, 192.70it/s]
# autocorr_time for each parameters= [33.43392783 34.04147578]
# $\displaystyle \mathrm{mean} = 1.975_{-0.154}^{0.121}$
# $\displaystyle \mathrm{sd} = 1.189_{-0.128}^{0.161}$
# max log prob =  -779.2263069384529
# mu= 1.8394648829431404
# sd= 1.2919732441471574
# --------------------------------
# true para log prob =  -784.8403585366691
# mu= 2
# sd= 1.5

# %% [markdown]
# # Conclusion : Similar effect as just one effect is implemented
# # _______________________________________________

# %% [markdown]
# ## Both measurement errpr and selection bias extends the area of high probi region

# %% [markdown]
# ## What is a meaingful error bar after implement two effect?
