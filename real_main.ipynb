# %%
import main

# %%
# (N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = False, bias_selec = False, seed = False)
import main 
N = 500 
mu_true = 0 
sd_true = 1 
error_sd = 0.5
Nsample_for_each_obs = 5
trial = 1 
th = -0.1
err =True
bias = False
seed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = False)
# Out:
# Population =500
# Mean, SD =0, 1
# Error on each data: Yes
# Error SD for each data =,0.5
# Number of samples for each data point =5
# Bias on obs data: None
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =None
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [01:42<00:00, 390.71it/s]
# autocorr_time for each parameters= [32.16696225 32.28484671]
# $\displaystyle \mathrm{mean} = 0.063_{-0.062}^{0.061}$
# $\displaystyle \mathrm{sd} = 0.981_{-0.045}^{0.048}$
# output of mean is done
# output of sd is done

# %%
# (N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = False, bias_selec = False, seed = False)
import main 
N = 500
mu_true = 0 
sd_true = 1 
error_sd = 2 
Nsample_for_each_obs = 5
trial = 1 
th = -0.1
err_selec = True
bias_selc = False
seed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = False)
# Out:
# Population =500
# Mean, SD =0, 1
# Error on each data: Yes
# Error SD for each data =,2
# Number of samples for each data point =5
# Bias on obs data: None
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =None
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [01:45<00:00, 378.36it/s]
# autocorr_time for each parameters= [31.70901199 32.12325608]
# $\displaystyle \mathrm{mean} = 0.050_{-0.116}^{0.116}$
# $\displaystyle \mathrm{sd} = 1.125_{-0.070}^{0.076}$
# output of mean is done
# output of sd is done

# %%
# (N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = False, bias_selec = False, seed = False)
import main 
N = 500
mu_true = 0 
sd_true = 1 
error_sd = 2 
Nsample_for_each_obs = 40
trial = 1 
th = -0.1
err_selec = True
bias_selc = False
seed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = False)
# Out:
# Population =500
# Mean, SD =0, 1
# Error on each data: Yes
# Error SD for each data =,2
# Number of samples for each data point =40
# Bias on obs data: None
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =None
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [04:50<00:00, 137.46it/s]
# autocorr_time for each parameters= [33.32752379 32.71325388]
# $\displaystyle \mathrm{mean} = 0.002_{-0.105}^{0.107}$
# $\displaystyle \mathrm{sd} = 0.471_{-0.069}^{0.078}$
# output of mean is done
# output of sd is done

# %%
import main 
N = 500
mu_true = 0 
sd_true = 1 
error_sd = 2 
Nsample_for_each_obs = 20
trial = 1 
th = -0.1
err_selec = True
bias_selc = False
seed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = False)
# Out:
# Population =500
# Mean, SD =0, 1
# Error on each data: Yes
# Error SD for each data =,2
# Number of samples for each data point =20
# Bias on obs data: None
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =None
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [03:06<00:00, 214.35it/s]
# autocorr_time for each parameters= [33.12299989 33.74549472]
# $\displaystyle \mathrm{mean} = -0.072_{-0.121}^{0.118}$
# $\displaystyle \mathrm{sd} = 0.650_{-0.070}^{0.078}$
# output of mean is done
# output of sd is done
