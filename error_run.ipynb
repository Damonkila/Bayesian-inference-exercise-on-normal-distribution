# %%
import main

# %%
# (N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = False, bias_selec = False, seed = False)
import main 
N = 500 
mu_true = 0 
sd_true = 1 
error_sd = 0.5
Nsample_for_each_obs = 5
trial = 1 
th = -0.1
err =True
bias = False
sdseed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = sdseed)
# Out:
# Population =500
# Mean, SD =0, 1
# Error on each data: Yes
# Error SD for each data =0.5
# Number of samples for each data point =5
# Bias on obs data: None
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =None
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [01:50<00:00, 360.74it/s]
# autocorr_time for each parameters= [30.24998274 32.49397399]
# $\displaystyle \mathrm{mean} = 0.018_{-0.058}^{0.057}$
# $\displaystyle \mathrm{sd} = 0.894_{-0.042}^{0.045}$
# output of mean is done
# output of sd is done

# %%
import main 
N = 500 
mu_true = 0 
sd_true = 1 
error_sd = 0.5
Nsample_for_each_obs = 20
trial = 1 
th = -0.1
err =True
bias = False
sdseed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = sdseed)
# Out:
# Population =500
# Mean, SD =0, 1
# Error on each data: Yes
# Error SD for each data =0.5
# Number of samples for each data point =20
# Bias on obs data: None
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =None
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [03:03<00:00, 218.49it/s]
# autocorr_time for each parameters= [33.19026518 32.84913227]
# $\displaystyle \mathrm{mean} = -0.026_{-0.062}^{0.061}$
# $\displaystyle \mathrm{sd} = 0.946_{-0.046}^{0.050}$
# output of mean is done
# output of sd is done

# %%
# (N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = False, bias_selec = False, seed = False)
import main 
N = 500
mu_true = 0 
sd_true = 1 
error_sd = 4
Nsample_for_each_obs = 5
trial = 1 
th = -0.1
err =True
bias = False
sdseed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = sdseed)
# Out:
# Population =500
# Mean, SD =0, 1
# Error on each data: Yes
# Error SD for each data =4
# Number of samples for each data point =5
# Bias on obs data: None
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =None
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [01:46<00:00, 375.79it/s]
# autocorr_time for each parameters= [32.31645306 32.32644462]
# $\displaystyle \mathrm{mean} = 0.082_{-0.217}^{0.210}$
# $\displaystyle \mathrm{sd} = 1.910_{-0.128}^{0.140}$
# output of mean is done
# output of sd is done

# %%
import main 
N = 500
mu_true = 0 
sd_true = 1 
error_sd = 4
Nsample_for_each_obs = 20
trial = 1 
th = -0.1
err =True
bias = False
sdseed = True
main.main_p(N, mu_true, sd_true, error_sd, Nsample_for_each_obs, trial, th, err_selec = err, bias_selec = bias, seed = sdseed)
# Out:
# Population =500
# Mean, SD =0, 1
# Error on each data: Yes
# Error SD for each data =4
# Number of samples for each data point =20
# Bias on obs data: None
# Number of walkers in para space =30
# Number of burnt steps =4000
# Number of trial for the run =1
# Seed of Rand Num =None
# trial= 1
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [02:59<00:00, 222.86it/s]
# autocorr_time for each parameters= [32.59819143 33.44856352]
# $\displaystyle \mathrm{mean} = -0.049_{-0.231}^{0.232}$
# $\displaystyle \mathrm{sd} = 1.192_{-0.131}^{0.145}$
# output of mean is done
# output of sd is done
